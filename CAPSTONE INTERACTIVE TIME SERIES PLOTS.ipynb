# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
np.random.seed(42)
pd.core.common.is_list_like=pd.api.types.is_list_like
import pandas_datareader.data as web

# %%
import pandas_datareader
import pandas_datareader.data as NET
from datetime import datetime

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go# Offline mode
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from  plotly.offline import plot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
##data frame with chronological time recent data shown last
dfx=pd.read_csv('forex2.csv')

# %%
## time series plot
usd_cad_data = go.Scatter(x=dfx['Date'].values,
                         y=dfx['usd_cad'].values)

# %%
layout = go.Layout(title='usd_cad', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))

# %%
fig = go.Figure(data=[usd_cad_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="648d9bce-8bb2-4d0d-b499-2c121c2d4c1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("648d9bce-8bb2-4d0d-b499-2c121c2d4c1f")) {                    Plotly.newPlot(                        "648d9bce-8bb2-4d0d-b499-2c121c2d4c1f",                        [{"type":"scatter","x":["1-Jan-19","2-Jan-19","3-Jan-19","4-Jan-19","7-Jan-19","8-Jan-19","9-Jan-19","10-Jan-19","11-Jan-19","14-Jan-19","15-Jan-19","16-Jan-19","17-Jan-19","18-Jan-19","21-Jan-19","22-Jan-19","23-Jan-19","24-Jan-19","25-Jan-19","28-Jan-19","29-Jan-19","30-Jan-19","31-Jan-19","1-Feb-19","4-Feb-19","5-Feb-19","6-Feb-19","7-Feb-19","8-Feb-19","11-Feb-19","12-Feb-19","13-Feb-19","14-Feb-19","15-Feb-19","18-Feb-19","19-Feb-19","20-Feb-19","21-Feb-19","
# ...

# %%
aud_usd_data = go.Scatter(x=dfx['Date'].values,
                         y=dfx['aud_usd'].values)

# %%
layout = go.Layout(title='aud_usd', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))

# %%
fig = go.Figure(data=[aud_usd_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="3db962c7-d478-4fd9-89b8-3be77c8fe314" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3db962c7-d478-4fd9-89b8-3be77c8fe314")) {                    Plotly.newPlot(                        "3db962c7-d478-4fd9-89b8-3be77c8fe314",                        [{"type":"scatter","x":["1-Jan-19","2-Jan-19","3-Jan-19","4-Jan-19","7-Jan-19","8-Jan-19","9-Jan-19","10-Jan-19","11-Jan-19","14-Jan-19","15-Jan-19","16-Jan-19","17-Jan-19","18-Jan-19","21-Jan-19","22-Jan-19","23-Jan-19","24-Jan-19","25-Jan-19","28-Jan-19","29-Jan-19","30-Jan-19","31-Jan-19","1-Feb-19","4-Feb-19","5-Feb-19","6-Feb-19","7-Feb-19","8-Feb-19","11-Feb-19","12-Feb-19","13-Feb-19","14-Feb-19","15-Feb-19","18-Feb-19","19-Feb-19","20-Feb-19","21-Feb-19","
# ...

# %%
gbp_usd_data = go.Scatter(x=dfx['Date'].values,
                         y=dfx['gbp_usd'].values)

# %%
layout = go.Layout(title='gbp_usd', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))

# %%
fig = go.Figure(data=[gbp_usd_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="997ab66b-6956-4c9a-8889-6119e9ad4c4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("997ab66b-6956-4c9a-8889-6119e9ad4c4f")) {                    Plotly.newPlot(                        "997ab66b-6956-4c9a-8889-6119e9ad4c4f",                        [{"type":"scatter","x":["1-Jan-19","2-Jan-19","3-Jan-19","4-Jan-19","7-Jan-19","8-Jan-19","9-Jan-19","10-Jan-19","11-Jan-19","14-Jan-19","15-Jan-19","16-Jan-19","17-Jan-19","18-Jan-19","21-Jan-19","22-Jan-19","23-Jan-19","24-Jan-19","25-Jan-19","28-Jan-19","29-Jan-19","30-Jan-19","31-Jan-19","1-Feb-19","4-Feb-19","5-Feb-19","6-Feb-19","7-Feb-19","8-Feb-19","11-Feb-19","12-Feb-19","13-Feb-19","14-Feb-19","15-Feb-19","18-Feb-19","19-Feb-19","20-Feb-19","21-Feb-19","
# ...

# %%
euro_usd_data = go.Scatter(x=dfx['Date'].values,
                         y=dfx['euro_usd'].values)
layout = go.Layout(title='euro_usd', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[euro_usd_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="40d1f1f0-fcbd-4da1-acff-71785bbd9876" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40d1f1f0-fcbd-4da1-acff-71785bbd9876")) {                    Plotly.newPlot(                        "40d1f1f0-fcbd-4da1-acff-71785bbd9876",                        [{"type":"scatter","x":["1-Jan-19","2-Jan-19","3-Jan-19","4-Jan-19","7-Jan-19","8-Jan-19","9-Jan-19","10-Jan-19","11-Jan-19","14-Jan-19","15-Jan-19","16-Jan-19","17-Jan-19","18-Jan-19","21-Jan-19","22-Jan-19","23-Jan-19","24-Jan-19","25-Jan-19","28-Jan-19","29-Jan-19","30-Jan-19","31-Jan-19","1-Feb-19","4-Feb-19","5-Feb-19","6-Feb-19","7-Feb-19","8-Feb-19","11-Feb-19","12-Feb-19","13-Feb-19","14-Feb-19","15-Feb-19","18-Feb-19","19-Feb-19","20-Feb-19","21-Feb-19","
# ...

# %%
usd_jpy_data = go.Scatter(x=dfx['Date'].values,
                         y=dfx['usd_jpy'].values)
layout = go.Layout(title='usd_jpy', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[usd_jpy_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="74e8e02c-c681-4b07-8163-f7c894c70f2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74e8e02c-c681-4b07-8163-f7c894c70f2d")) {                    Plotly.newPlot(                        "74e8e02c-c681-4b07-8163-f7c894c70f2d",                        [{"type":"scatter","x":["1-Jan-19","2-Jan-19","3-Jan-19","4-Jan-19","7-Jan-19","8-Jan-19","9-Jan-19","10-Jan-19","11-Jan-19","14-Jan-19","15-Jan-19","16-Jan-19","17-Jan-19","18-Jan-19","21-Jan-19","22-Jan-19","23-Jan-19","24-Jan-19","25-Jan-19","28-Jan-19","29-Jan-19","30-Jan-19","31-Jan-19","1-Feb-19","4-Feb-19","5-Feb-19","6-Feb-19","7-Feb-19","8-Feb-19","11-Feb-19","12-Feb-19","13-Feb-19","14-Feb-19","15-Feb-19","18-Feb-19","19-Feb-19","20-Feb-19","21-Feb-19","
# ...

# %%
dfc=pd.read_csv('crypto2.csv')
dfc
# Out:
#           DATE  XRP_USDp      XRP_USDv  USDT_USDp     USDT_USDv     ETH_USDp  \
# 0     1/1/2019  0.364771  4.493476e+08   1.018335  3.139235e+09   140.819412
# 1     1/2/2019  0.375243  5.432167e+08   1.024012  4.442755e+09   155.047684
# 2     1/3/2019  0.360224  4.388738e+08   1.019473  3.487203e+09   149.135010
# 3     1/4/2019  0.356747  4.506339e+08   1.017200  3.895787e+09   154.581940
# 4     1/5/2019  0.355275  4.520902e+08   1.018489  3.993807e+09   155.638596
# ..         ...       ...           ...        ...           ...          ...
# 960  8/18/2021  1.146097  7.559386e+09   1.000474  7.956238e+10  3020.089844
# 961  8/19/2021  1.232842  6.781868e+09   0.999685  7.953519e+10  3182.702148
# 962  8/20/2021  1.263222  6.600354e+09   1.000668  7.500765e+10  3286.935303
# 963  8/21/2021  1.216473  4.955470e+09   1.000710  7.754619e+10  3226.083984
# 964  8/22/2021  1.243458  4.513352e+09   1.000283  7.027238e+10  3254.117188
#
# ...

# %%
XRP_USDp_data = go.Scatter(x=dfc['DATE'].values,
                         y=dfc['XRP_USDp'].values)
layout = go.Layout(title='XRP_USDp', xaxis=dict(title='DATE'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[XRP_USDp_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="181b91bd-35c3-4cc0-ab14-d011be048192" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("181b91bd-35c3-4cc0-ab14-d011be048192")) {                    Plotly.newPlot(                        "181b91bd-35c3-4cc0-ab14-d011be048192",                        [{"type":"scatter","x":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/12/2019","1/13/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/19/2019","1/20/2019","1/21/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/26/2019","1/27/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/2/2019","2/3/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8
# ...

# %%
USDT_USDp_data = go.Scatter(x=dfc['DATE'].values,
                         y=dfc['USDT_USDp'].values)
layout = go.Layout(title='USDT_USDp', xaxis=dict(title='DATE'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[USDT_USDp_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="2dab5b56-d4ff-4685-93e5-c0074334124e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dab5b56-d4ff-4685-93e5-c0074334124e")) {                    Plotly.newPlot(                        "2dab5b56-d4ff-4685-93e5-c0074334124e",                        [{"type":"scatter","x":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/12/2019","1/13/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/19/2019","1/20/2019","1/21/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/26/2019","1/27/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/2/2019","2/3/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8
# ...

# %%
ETH_USDp_data = go.Scatter(x=dfc['DATE'].values,
                         y=dfc['ETH_USDp'].values)
layout = go.Layout(title='ETH_USDp', xaxis=dict(title='DATE'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[ETH_USDp_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="7bfbf6e4-1f29-471b-9c17-02fd611d853f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bfbf6e4-1f29-471b-9c17-02fd611d853f")) {                    Plotly.newPlot(                        "7bfbf6e4-1f29-471b-9c17-02fd611d853f",                        [{"type":"scatter","x":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/12/2019","1/13/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/19/2019","1/20/2019","1/21/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/26/2019","1/27/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/2/2019","2/3/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8
# ...

# %%
BTC_USDp_data = go.Scatter(x=dfc['DATE'].values,
                         y=dfc['BTC_USDp'].values)
layout = go.Layout(title='BTC_USDp', xaxis=dict(title='DATE'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[BTC_USDp_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="e6a8f30a-aff5-45d4-b69e-1e39a342b2c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6a8f30a-aff5-45d4-b69e-1e39a342b2c6")) {                    Plotly.newPlot(                        "e6a8f30a-aff5-45d4-b69e-1e39a342b2c6",                        [{"type":"scatter","x":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/12/2019","1/13/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/19/2019","1/20/2019","1/21/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/26/2019","1/27/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/2/2019","2/3/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8
# ...

# %%
DOGE_USDp_data = go.Scatter(x=dfc['DATE'].values,
                         y=dfc['DOGE_USDp'].values)
layout = go.Layout(title='DOGE_USDp', xaxis=dict(title='DATE'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[DOGE_USDp_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="92afefa9-9c3b-4e38-beee-d78f8af08dbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92afefa9-9c3b-4e38-beee-d78f8af08dbb")) {                    Plotly.newPlot(                        "92afefa9-9c3b-4e38-beee-d78f8af08dbb",                        [{"type":"scatter","x":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/12/2019","1/13/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/19/2019","1/20/2019","1/21/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/26/2019","1/27/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/2/2019","2/3/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8
# ...

# %%
BNB_USDp_data = go.Scatter(x=dfc['DATE'].values,
                         y=dfc['BNB_USDp'].values)
layout = go.Layout(title='BNB_USDp', xaxis=dict(title='DATE'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[BNB_USDp_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="9f399e18-e0bc-4bbc-a31e-35e82af63d51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f399e18-e0bc-4bbc-a31e-35e82af63d51")) {                    Plotly.newPlot(                        "9f399e18-e0bc-4bbc-a31e-35e82af63d51",                        [{"type":"scatter","x":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/12/2019","1/13/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/19/2019","1/20/2019","1/21/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/26/2019","1/27/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/2/2019","2/3/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8
# ...

# %%
dfs=pd.read_csv('stocks2.csv')
dfs
# Out:
#           Date       NYC      DJIA  NSDQBTCH     RUSS   SPFIVE
# 0     1/2/2019  11383.53  22686.22   3061.26  1385.23  2510.03
# 1     1/3/2019  11190.44  23433.16   3071.68  1351.87  2447.89
# 2     1/4/2019  11533.34  23531.35   3228.22  1398.34  2531.94
# 3     1/7/2019  11605.96  23787.45   3335.04  1409.36  2549.69
# 4     1/8/2019  11716.23  23879.12   3357.50  1423.71  2574.41
# ..         ...       ...       ...       ...      ...      ...
# 678  9/10/2021  16563.48  34607.72   5366.18  2502.26  4458.58
# 679  9/13/2021  16635.39  34869.63   5301.02  2507.11  4462.58
# 680  9/14/2021  16497.23  34577.57   5282.71  2492.32  4480.70
# 681  9/15/2021  16626.88  34814.39   5333.00  2513.20  4473.75
# 682  9/16/2021  16576.77  34751.32   5359.97  2511.25  4432.99
#
# [683 rows x 6 columns]

# %%
NYC_data = go.Scatter(x=dfs['Date'].values,
                         y=dfs['NYC'].values)
layout = go.Layout(title='NYC', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[NYC_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="fe5a76b8-c7da-4013-a451-71670e42e6f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe5a76b8-c7da-4013-a451-71670e42e6f6")) {                    Plotly.newPlot(                        "fe5a76b8-c7da-4013-a451-71670e42e6f6",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
SPFIVE_data = go.Scatter(x=dfs['Date'].values,
                         y=dfs['SPFIVE'].values)
layout = go.Layout(title='SPFIVE', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[SPFIVE_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="48978e51-e415-4c73-9926-2e983c761fd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48978e51-e415-4c73-9926-2e983c761fd0")) {                    Plotly.newPlot(                        "48978e51-e415-4c73-9926-2e983c761fd0",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
NSDQBTCH_data = go.Scatter(x=dfs['Date'].values,
                         y=dfs['NSDQBTCH'].values)
layout = go.Layout(title='NASDAQ BIOTECH INDEX', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[NSDQBTCH_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="2ce85396-2447-4a4e-a51b-06fa102523ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ce85396-2447-4a4e-a51b-06fa102523ba")) {                    Plotly.newPlot(                        "2ce85396-2447-4a4e-a51b-06fa102523ba",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
DJIA_data = go.Scatter(x=dfs['Date'].values,
                         y=dfs['DJIA'].values)
layout = go.Layout(title='DJIA', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[DJIA_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="5d27a7d6-d472-408a-babf-711ac1f6f290" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d27a7d6-d472-408a-babf-711ac1f6f290")) {                    Plotly.newPlot(                        "5d27a7d6-d472-408a-babf-711ac1f6f290",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
RUSS_data = go.Scatter(x=dfs['Date'].values,
                         y=dfs['RUSS'].values)
layout = go.Layout(title='RUSS', xaxis=dict(title='Date'),
                   yaxis=dict(title='(rate)'))
fig = go.Figure(data=[RUSS_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="bc602fde-9b7c-4718-b89f-0de98660ebfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc602fde-9b7c-4718-b89f-0de98660ebfe")) {                    Plotly.newPlot(                        "bc602fde-9b7c-4718-b89f-0de98660ebfe",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
dfcm=pd.read_csv('commodities2.csv')
dfcm
# Out:
#           date    GOLD  DJGRAIN  DJMETAL  WHEAT_F     SB_F  OIL_F
# 0     1/2/2019  1284.1   180.86   149.32   463.12   887.75  53.10
# 1     1/3/2019  1294.8   182.43   150.79   466.75   878.50  53.90
# 2     1/4/2019  1285.8   182.57   151.52   480.50   880.88  54.41
# 3     1/7/2019  1289.9   181.72   151.06   476.00   880.75  55.59
# 4     1/8/2019  1285.9   182.70   151.61   472.25   877.50  56.33
# ..         ...     ...      ...      ...      ...      ...    ...
# 660  8/16/2021  1789.8   278.20   219.62   761.75  1374.12  67.29
# 661  8/17/2021  1787.8   274.88   218.08   733.50  1363.00  66.59
# 662  8/18/2021  1784.4   274.61   215.75   736.12  1350.75  65.46
# 663  8/19/2021  1783.1   268.55   213.85   727.00  1322.00  63.69
# 664  8/20/2021  1784.0   262.55   214.31   715.00  1292.25  62.32
#
# [665 rows x 7 columns]

# %%
GOLD_data = go.Scatter(x=dfcm['date'].values,
                         y=dfcm['GOLD'].values)
layout = go.Layout(title='GOLD', xaxis=dict(title='date'),
                   yaxis=dict(title='(GOLD)'))
fig = go.Figure(data=[GOLD_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="b0c44dc8-dc36-4608-b410-2883d6d47228" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0c44dc8-dc36-4608-b410-2883d6d47228")) {                    Plotly.newPlot(                        "b0c44dc8-dc36-4608-b410-2883d6d47228",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
OIL_F_data = go.Scatter(x=dfcm['date'].values,
                         y=dfcm['OIL_F'].values)
layout = go.Layout(title='OIL_F', xaxis=dict(title='date'),
                   yaxis=dict(title='(OIL_F)'))
fig = go.Figure(data=[GOLD_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="a3260526-9e6a-4054-a201-601a38b51351" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3260526-9e6a-4054-a201-601a38b51351")) {                    Plotly.newPlot(                        "a3260526-9e6a-4054-a201-601a38b51351",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
DJGRAIN_data = go.Scatter(x=dfcm['date'].values,
                         y=dfcm['DJGRAIN'].values)
layout = go.Layout(title='DJGRAIN', xaxis=dict(title='date'),
                   yaxis=dict(title='(OIL_F)'))
fig = go.Figure(data=[DJGRAIN_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="bdf37fed-5182-49b5-84e2-8ec66921c93b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdf37fed-5182-49b5-84e2-8ec66921c93b")) {                    Plotly.newPlot(                        "bdf37fed-5182-49b5-84e2-8ec66921c93b",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
DJMETAL_data = go.Scatter(x=dfcm['date'].values,
                         y=dfcm['DJMETAL'].values)
layout = go.Layout(title='DJMETAL', xaxis=dict(title='date'),
                   yaxis=dict(title='(DJMETAL)'))
fig = go.Figure(data=[DJMETAL_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="81d1882b-dcc6-4a15-9581-1c4bd45cae82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81d1882b-dcc6-4a15-9581-1c4bd45cae82")) {                    Plotly.newPlot(                        "81d1882b-dcc6-4a15-9581-1c4bd45cae82",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
dft=pd.read_csv('tycr2.csv')
dft
# Out:
#           Date  oneMo   2Mo   3Mo  sixMo  oneYr   2Yr   3Yr  fiveYr   7Yr  \
# 0     1/2/2019   2.40  2.40  2.42   2.51   2.60  2.50  2.47    2.49  2.56
# 1     1/3/2019   2.42  2.42  2.41   2.47   2.50  2.39  2.35    2.37  2.44
# 2     1/4/2019   2.40  2.42  2.42   2.51   2.57  2.50  2.47    2.49  2.56
# 3     1/7/2019   2.42  2.42  2.45   2.54   2.58  2.53  2.51    2.53  2.60
# 4     1/8/2019   2.40  2.42  2.46   2.54   2.60  2.58  2.57    2.58  2.63
# ..         ...    ...   ...   ...    ...    ...   ...   ...     ...   ...
# 656  8/13/2021   0.04  0.05  0.06   0.05   0.08  0.23  0.44    0.79  1.08
# 657  8/16/2021   0.04  0.05  0.06   0.05   0.08  0.21  0.42    0.75  1.04
# 658  8/17/2021   0.03  0.05  0.07   0.06   0.07  0.23  0.43    0.77  1.05
# 659  8/18/2021   0.03  0.05  0.07   0.05   0.07  0.23  0.43    0.79  1.06
# 660  8/19/2021   0.04  0.05  0.06   0.05   0.06  0.22  0.44    0.78  1.04
#
#      tenYr  20Yr  thtYr
# 0     2.66  2.83   2.97
# 1     2.56  2.75   2.92
# ...

# %%
oneMo_data = go.Scatter(x=dft['Date'].values,
                         y=dft['oneMo'].values)
layout = go.Layout(title='oneMo', xaxis=dict(title='Date'),
                   yaxis=dict(title='(DJMETAL)'))
fig = go.Figure(data=[oneMo_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="83d52af3-1dfa-4a17-a971-3fe389c2ac23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83d52af3-1dfa-4a17-a971-3fe389c2ac23")) {                    Plotly.newPlot(                        "83d52af3-1dfa-4a17-a971-3fe389c2ac23",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
sixMo_data = go.Scatter(x=dft['Date'].values,
                         y=dft['sixMo'].values)
layout = go.Layout(title='sixMo', xaxis=dict(title='Date'),
                   yaxis=dict(title='(sixMo)'))
fig = go.Figure(data=[sixMo_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="03dac8ae-1857-4852-8131-063c5c9f1fc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03dac8ae-1857-4852-8131-063c5c9f1fc7")) {                    Plotly.newPlot(                        "03dac8ae-1857-4852-8131-063c5c9f1fc7",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
fiveYr_data = go.Scatter(x=dft['Date'].values,
                         y=dft['fiveYr'].values)
layout = go.Layout(title='fiveYr', xaxis=dict(title='Date'),
                   yaxis=dict(title='(fiveYr)'))
fig = go.Figure(data=[fiveYr_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="f2ea71ac-7a6d-4d83-944b-696f11755402" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2ea71ac-7a6d-4d83-944b-696f11755402")) {                    Plotly.newPlot(                        "f2ea71ac-7a6d-4d83-944b-696f11755402",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
tenYr_data = go.Scatter(x=dft['Date'].values,
                         y=dft['tenYr'].values)
layout = go.Layout(title='tenYr', xaxis=dict(title='Date'),
                   yaxis=dict(title='(tenYr)'))
fig = go.Figure(data=[tenYr_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="190f8291-233e-4ab0-94d2-47e790d871f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("190f8291-233e-4ab0-94d2-47e790d871f3")) {                    Plotly.newPlot(                        "190f8291-233e-4ab0-94d2-47e790d871f3",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...

# %%
thtYr_data = go.Scatter(x=dft['Date'].values,
                         y=dft['thtYr'].values)
layout = go.Layout(title='thtYr', xaxis=dict(title='Date'),
                   yaxis=dict(title='(thtYr)'))
fig = go.Figure(data=[thtYr_data ], layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div>                            <div id="960b3a94-cfb9-4f9f-82d2-8bf808a411ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("960b3a94-cfb9-4f9f-82d2-8bf808a411ee")) {                    Plotly.newPlot(                        "960b3a94-cfb9-4f9f-82d2-8bf808a411ee",                        [{"type":"scatter","x":["1/2/2019","1/3/2019","1/4/2019","1/7/2019","1/8/2019","1/9/2019","1/10/2019","1/11/2019","1/14/2019","1/15/2019","1/16/2019","1/17/2019","1/18/2019","1/22/2019","1/23/2019","1/24/2019","1/25/2019","1/28/2019","1/29/2019","1/30/2019","1/31/2019","2/1/2019","2/4/2019","2/5/2019","2/6/2019","2/7/2019","2/8/2019","2/11/2019","2/12/2019","2/13/2019","2/14/2019","2/15/2019","2/19/2019","2/20/2019","2/21/2019","2/22/2019","2/25/2019","2/26/2019",
# ...
