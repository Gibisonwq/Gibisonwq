# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
np.random.seed(42)
pd.core.common.is_list_like=pd.api.types.is_list_like
import pandas_datareader.data as web

# %%
import pandas_datareader
import pandas_datareader.data as NET
from datetime import datetime

# %%
df=pd.read_csv('coviddataUSA.csv')
df
# Out:
#           date  totalcases  newcases  totaldeaths  newdeaths  icupatients  \
# 0    7/26/2021    34533058     89297       610951         60         7923
# 1    7/25/2021    34443761     15711       610891         56         7923
# 2    7/24/2021    34428050     27395       610835        115         7923
# 3    7/23/2021    34400655    118791       610720        525         7925
# 4    7/22/2021    34281864     55058       610195        315         7634
# ..         ...         ...       ...          ...        ...          ...
# 546  1/27/2020           5         0            0          0            0
# 547  1/26/2020           5         3            0          0            0
# 548  1/25/2020           2         0            0          0            0
# 549  1/24/2020           2         1            0          0            0
# 550  1/23/2020           1         0            0          0            0
#
#      hosppatients  newtests  totaltests  positiverate  totalvaccs  newvaccs  \
# ...

# %%
df.describe()
# Out:
#          totalcases       newcases    totaldeaths    newdeaths   icupatients  \
# count  5.510000e+02     551.000000     551.000000   551.000000    551.000000
# mean   1.452508e+07   62673.424682  287852.762250  1108.803993   8707.551724
# std    1.311335e+07   62926.577811  215001.806109   972.207429   8385.069518
# min    1.000000e+00       0.000000       0.000000     0.000000      0.000000
# 25%    1.970504e+06   22732.000000  114590.500000   430.500000      0.000000
# 50%    8.599971e+06   44251.000000  225697.000000   878.000000   8301.000000
# 75%    2.925935e+07   70359.000000  531744.000000  1510.000000  12476.500000
# max    3.453306e+07  300462.000000  610951.000000  4461.000000  28889.000000
#
#         hosppatients      newtests    totaltests  positiverate    totalvaccs  \
# count     551.000000  5.510000e+02  5.510000e+02    551.000000  5.510000e+02
# mean    34257.248639  8.751248e+05  1.936400e+08      0.066227  2.963325e+07
# ...

# %%
## QQ PLOTS 
import statsmodels.api as sm
import pylab as py

# %%
totalcases=df['totalcases']
newcases=df['newcases']
totaldeaths=df['totaldeaths']
newdeaths=['newdeaths']
icupatients=['icupatients']
hosppatients=['hosppatients']
newtests=['newtests']
totaltests=['totaltests']
positiverate=['positiverate']
totalvaccs=['totalvaccs']
newvaccs=['newvaccs']
stringencyindex=['stringencyindex']

# %%
sm.qqplot(totalcases, line ='45')
py.show()
sm.qqplot(newcases, line ='45')
py.show()
sm.qqplot(totaldeaths, line ='45')
py.show()

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix   
  
    

# selecting numerical features
features = ['totalcases', 'newcases',
            'totaldeaths','newdeaths','icupatients','hosppatients','newtests','totaltests','positiverate','totalvaccs','newvaccs','stringencyindex']
   
# plotting the scatter matrix
# with the features
scatter_matrix(df[features])
plt.show()
# Out:
# C:\Users\Gibson\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
import os
import pickle
from functools import reduce
from operator import mul

import pandas as pd
import numpy as np

from statsmodels.regression.linear_model import OLS
from sklearn import linear_model
from sklearn.decomposition import PCA

import holoviews as hv
import hvplot
import hvplot.pandas

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Construct the Correlation Matrix
corr_matrix = df.corr(method='pearson')
corr_matrix = np.abs(corr_matrix) * 100

# %%
#Plot a Correlation Matrix Heat Map
f, ax = plt.subplots(figsize=(8,8))
sns.heatmap(corr_matrix , cbar=True, annot=True, square=True,
            fmt='.0f', annot_kws={'size':8}, alpha=0.6)
plt.title('Correlation of Covid 19 variables', fontsize=16)
plt.show()

# %%
# DENSITY PLOTS 
#returns calculation

df.totalcases.plot.density(color='green')
plt.title('Density Plot for totalcases')
plt.show()

df.newcases.plot.density(color='green')
plt.title('Density Plot for newcases')
plt.show()
 
df.totaldeaths.plot.density(color='green')
plt.title('Density Plot for totaldeaths')
plt.show()

df.newdeaths.plot.density(color='green')
plt.title('Density Plot for newdeaths')
plt.show()

df.icupatients.plot.density(color='green')
plt.title('Density Plot for icupatients')
plt.show()

df.hosppatients.plot.density(color='green')
plt.title('Density Plot for hosppatients')
plt.show()

df.newtests.plot.density(color='green')
plt.title('Density Plot for newtests')
plt.show()
df.totaltests.plot.density(color='green')
plt.title('Density Plot for totaltests')
plt.show()
df.positiverate.plot.density(color='green')
plt.title('Density Plot for positiverate')
plt.show()
df.totalvaccs.plot.density(color='green')
plt.title('Density Plot for totalvaccs')
plt.show()
df.newvaccs.plot.density(color='green')
plt.title('Density Plot for newvaccs')
plt.show()
df.stringencyindex.plot.density(color='green')
plt.title('Density Plot for stringencyindex')
plt.show()

# %%
# totalcases

totalcases=df['totalcases']
newcases=df['newcases']
totaldeaths=df['totaldeaths']
newdeaths=['newdeaths']
icupatients=['icupatients']
hosppatients=['hosppatients']
newtests=['newtests']
totaltests=['totaltests']
positiverate=['positiverate']
totalvaccs=['totalvaccs']
newvaccs=['newvaccs']
stringencyindex=['stringencyindex']
date=df['date']

x=date
y=totalcases

# %%
plt.plot(x,y)
plt.xlabel('date')
plt.ylabel('total deaths')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df.date,df.newdeaths)
plt.plot(df.date,df.totalcases)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#         date  totalcases  newcases  totaldeaths  newdeaths  icupatients  \
# 0  7/26/2021    34533058     89297       610951         60         7923
# 1  7/25/2021    34443761     15711       610891         56         7923
# 2  7/24/2021    34428050     27395       610835        115         7923
# 3  7/23/2021    34400655    118791       610720        525         7925
# 4  7/22/2021    34281864     55058       610195        315         7634
#
#    hosppatients  newtests  totaltests  positiverate  totalvaccs  newvaccs  \
# 0         29596    236897   480772408         0.044   163025726    778996
# 1         29596    236897   480772408         0.044   163025726    778996
# 2         29596    236897   480772408         0.044   162725812    676050
# 3         29607    236897   480772408         0.044   162435276    600157
# 4         28414    236897   480772408         0.044   162174165    660898
#
#    stringencyindex
# 0            49.54
# 1            49.54
# 2            49.54
# ...

# %%
##selecting the data for dates after 23/08/20 and puting them into a new frame

# %%
##creating a  new column in the existing data frame

# %%
df.head()
# Out:
#         date  totalcases  newcases  totaldeaths  newdeaths  icupatients  \
# 0  7/26/2021    34533058     89297       610951         60         7923
# 1  7/25/2021    34443761     15711       610891         56         7923
# 2  7/24/2021    34428050     27395       610835        115         7923
# 3  7/23/2021    34400655    118791       610720        525         7925
# 4  7/22/2021    34281864     55058       610195        315         7634
#
#    hosppatients  newtests  totaltests  positiverate  totalvaccs  newvaccs  \
# 0         29596    236897   480772408         0.044   163025726    778996
# 1         29596    236897   480772408         0.044   163025726    778996
# 2         29596    236897   480772408         0.044   162725812    676050
# 3         29607    236897   480772408         0.044   162435276    600157
# 4         28414    236897   480772408         0.044   162174165    660898
#
#    stringencyindex
# 0            49.54
# 1            49.54
# 2            49.54
# ...

# %%
df.describe()
# Out:
#          totalcases       newcases    totaldeaths    newdeaths   icupatients  \
# count  5.510000e+02     551.000000     551.000000   551.000000    551.000000
# mean   1.452508e+07   62673.424682  287852.762250  1108.803993   8707.551724
# std    1.311335e+07   62926.577811  215001.806109   972.207429   8385.069518
# min    1.000000e+00       0.000000       0.000000     0.000000      0.000000
# 25%    1.970504e+06   22732.000000  114590.500000   430.500000      0.000000
# 50%    8.599971e+06   44251.000000  225697.000000   878.000000   8301.000000
# 75%    2.925935e+07   70359.000000  531744.000000  1510.000000  12476.500000
# max    3.453306e+07  300462.000000  610951.000000  4461.000000  28889.000000
#
#         hosppatients      newtests    totaltests  positiverate    totalvaccs  \
# count     551.000000  5.510000e+02  5.510000e+02    551.000000  5.510000e+02
# mean    34257.248639  8.751248e+05  1.936400e+08      0.066227  2.963325e+07
# ...

# %%
plt.plot(x,y)
plt.xlabel('date')
plt.ylabel('newdeaths')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.xlabel('year')
plt.ylabel('total deaths')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('coviddataUSA.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()
