# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
np.random.seed(42)
pd.core.common.is_list_like=pd.api.types.is_list_like
import pandas_datareader.data as web

# %%
import pandas_datareader
import pandas_datareader.data as NET
from datetime import datetime

# %%
df=pd.read_csv('forex.csv')
df
# Out:
#           Date  usd_cad  aud_usd  usd_jpy  gbp_usd  euro_usd  euro_jpy
# 0    20-Aug-21   1.2821   0.7134   109.80   1.3621    1.1696    128.42
# 1    19-Aug-21   1.2826   0.7146   109.72   1.3638    1.1674    128.09
# 2    18-Aug-21   1.2655   0.7231   109.74   1.3755    1.1710    128.51
# 3    17-Aug-21   1.2630   0.7249   109.57   1.3739    1.1708    128.30
# 4    16-Aug-21   1.2572   0.7337   109.23   1.3850    1.1777    128.64
# ..         ...      ...      ...      ...      ...       ...       ...
# 684   7-Jan-19   1.3298   0.7147   108.72   1.2778    1.1476    124.75
# 685   4-Jan-19   1.3374   0.7112   108.53   1.2726    1.1395    123.67
# 686   3-Jan-19   1.3489   0.7005   107.67   1.2631    1.1394    122.67
# 687   2-Jan-19   1.3578   0.6984   108.88   1.2607    1.1343    123.51
# 688   1-Jan-19   1.3639   0.7052   109.72   1.2751    1.1464    125.78
#
# [689 rows x 7 columns]

# %%
df.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd    euro_jpy
# count  689.000000  689.000000  689.000000  689.000000  689.000000  689.000000
# mean     1.313135    0.710071  107.975762    1.305940    1.147134  123.825660
# std      0.046564    0.041254    2.192877    0.056612    0.042962    4.360793
# min      1.203200    0.574100  102.340000    1.148500    1.069000  114.570000
# 25%      1.281400    0.685100  106.290000    1.264700    1.112000  120.570000
# 50%      1.320600    0.707500  108.420000    1.300600    1.132900  123.690000
# 75%      1.335400    0.737200  109.580000    1.350700    1.184900  126.300000
# max      1.451000    0.796700  112.170000    1.420900    1.232500  133.950000

# %%
pb4covid.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd    euro_jpy
# count  276.000000  276.000000  276.000000  276.000000  276.000000  276.000000
# mean     1.325138    0.694871  109.042717    1.278480    1.118886  122.013841
# std      0.012694    0.014063    1.555646    0.033247    0.013195    2.630981
# min      1.296300    0.670200  105.290000    1.203400    1.089800  116.220000
# 25%      1.315875    0.683950  108.112500    1.254250    1.108675  120.357500
# 50%      1.325950    0.692300  108.840000    1.287700    1.118750  121.750000
# 75%      1.333400    0.708000  109.970000    1.304975    1.128425  124.462500
# max      1.357800    0.727200  112.170000    1.333700    1.154300  127.330000

# %%
pfaftcovid.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd    euro_jpy
# count  411.000000  411.000000  411.000000  411.000000  411.000000  411.000000
# mean     1.305027    0.720282  107.250584    1.324318    1.166050  125.026423
# std      0.057955    0.049629    2.266499    0.061484    0.045643    4.853023
# min      1.203200    0.574100  102.340000    1.148500    1.069000  114.570000
# 25%      1.258050    0.688950  105.400000    1.279800    1.125600  120.895000
# 50%      1.308100    0.728500  107.310000    1.322300    1.181300  125.330000
# 75%      1.340050    0.764000  109.235000    1.382200    1.203300  129.350000
# max      1.451000    0.796700  112.110000    1.420900    1.232500  133.950000

# %%
#returns calculation
usd_cad_RETURNS= df['usd_cad'].pct_change(1)
aud_usd_RETURNS = df['aud_usd'].pct_change(1)
usd_jpy_RETURNS = df['usd_jpy'].pct_change(1)
gbp_usd_RETURNS = df['gbp_usd'].pct_change(1)
euro_usd_RETURNS = df['euro_usd'].pct_change(1)

# %%
## QQ PLOTS 
import statsmodels.api as sm
import pylab as py

# %%
sm.qqplot(usd_cad_RETURNS, line ='45')
py.show()
sm.qqplot(aud_usd_RETURNS, line ='45')
py.show()
sm.qqplot(usd_jpy_RETURNS, line ='45')
py.show()
sm.qqplot(gbp_usd_RETURNS, line ='45')
py.show()
sm.qqplot(euro_usd_RETURNS, line ='45')
py.show()

# %%
# DENSITY PLOTS 
#returns calculation


df.usd_cad.plot.density(color='green')
plt.title('Density Plot for usd_cad')
plt.show()

df.aud_usd.plot.density(color='green')
plt.title('Density Plot for aud_usd')
plt.show()
 
df.usd_jpy.plot.density(color='green')
plt.title('Density Plot for usd_jpy')
plt.show()

df.gbp_usd.plot.density(color='green')
plt.title('Density Plot for gbp_usd')
plt.show()

df.euro_usd.plot.density(color='green')
plt.title('Density Plot for euro_usd')
plt.show()

# %%
from scipy.stats import shapiro
from scipy.stats import shapiro

# %%
usd_cad_RETURNS= df['usd_cad'].pct_change(1)
aud_usd_RETURNS = df['aud_usd'].pct_change(1)
usd_jpy_RETURNS = df['usd_jpy'].pct_change(1)
gbp_usd_RETURNS = df['gbp_usd'].pct_change(1)
euro_usd_RETURNS = df['euro_usd'].pct_change(1)

N1=usd_cad_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('usd_cad_RETURNS data is normally distributed')
    
else:
    print('usd_cad_RETURNS data is not  normally distributed')
 
 
from scipy.stats import shapiro
from scipy.stats import shapiro

N1=aud_usd_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('aud_usd_RETURNS data is normally distributed')
    
else:
    print('aud_usd_RETURNS data is not  normally distributed')
    
    
from scipy.stats import shapiro
from scipy.stats import shapiro

N1=usd_cad_RETURNS= df['usd_cad'].pct_change(1)
aud_usd_RETURNS = df['aud_usd'].pct_change(1)
usd_jpy_RETURNS = df['usd_jpy'].pct_change(1)
gbp_usd_RETURNS = df['gbp_usd'].pct_change(1)
euro_usd_RETURNS = df['euro_usd'].pct_change(1)

N1=usd_cad_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('usd_cad_RETURNS data is normally distributed')
    
else:
    print('usd_cad_RETURNS data is not  normally distributed')
 
 
from scipy.stats import shapiro
from scipy.stats import shapiro

N1=aud_usd_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('aud_usd_RETURNS data is normally distributed')
    
else:
    print('aud_usd_RETURNS data is not  normally distributed')
    
    
from scipy.stats import shapiro
from scipy.stats import shapiro

N1=usd_jpy_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('usd_jpy_RETURNS data is normally distributed')
    
else:
    print('usd_jpy_RETURNS data is not  normally distributed')
 

from scipy.stats import shapiro
from scipy.stats import shapiro

N1=gbp_usd_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('gbp_usd_RETURNS data is normally distributed')
    
else:
    print('gbp_usd_RETURNS data is not  normally distributed')
    
    from scipy.stats import shapiro
from scipy.stats import shapiro

N1=euro_usd_RETURNS
stat,p=shapiro(N1)
print('stat=%.3f,p=%.3f\n'%(stat,p))
if p>0.05:
    print('euro_usd_RETURNS data is normally distributed')
    
else:
    print('euro_usd_RETURNS data is not  normally distributed')
# Out:
# stat=nan,p=1.000
#
# usd_cad_RETURNS data is normally distributed
# stat=nan,p=1.000
#
# aud_usd_RETURNS data is normally distributed
# stat=nan,p=1.000
#
# usd_cad_RETURNS data is normally distributed
# stat=nan,p=1.000
#
# aud_usd_RETURNS data is normally distributed
# stat=nan,p=1.000
#
# usd_jpy_RETURNS data is normally distributed
# stat=nan,p=1.000
#
# gbp_usd_RETURNS data is normally distributed
# stat=nan,p=1.000
#
# euro_usd_RETURNS data is normally distributed

# %%
##kurtosis
from scipy.stats import kurtosis
print("gbp_usd_RETURNS kurtosis is % s" 
                              %(gbp_usd_RETURNS.kurtosis()))
print("aud_usd_RETURNS kurtosis is % s" 
                              %(aud_usd_RETURNS.kurtosis()))

print("usd_cad_RETURNS kurtosis is % s" 
                              %(usd_cad_RETURNS.kurtosis()))
print("aud_usd_RETURNS kurtosis is % s" 
                              %(aud_usd_RETURNS.kurtosis()))

print("usd_jpy_RETURNS  kurtosis is % s" 
                              %(usd_jpy_RETURNS .kurtosis()))
print("euro_usd_RETURNS kurtosis is % s" 
                              %(euro_usd_RETURNS.kurtosis()))
# Out:
# gbp_usd_RETURNS kurtosis is 4.379183386214874
# aud_usd_RETURNS kurtosis is 5.714363512092199
# usd_cad_RETURNS kurtosis is 2.8015369541799657
# aud_usd_RETURNS kurtosis is 5.714363512092199
# usd_jpy_RETURNS  kurtosis is 11.693106223596612
# euro_usd_RETURNS kurtosis is 1.932038280458305

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix   
  
# selecting numerical features
features = ['gbp_usd', 'aud_usd',
            'usd_cad','usd_jpy','euro_usd']
   
# plotting the scatter matrix
# with the features
scatter_matrix(df[features])
plt.show()
# Out:
# C:\Users\Gibson\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
import os
import pickle
from functools import reduce
from operator import mul

import pandas as pd
import numpy as np

from statsmodels.regression.linear_model import OLS
from sklearn import linear_model
from sklearn.decomposition import PCA

import holoviews as hv
import hvplot
import hvplot.pandas

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Construct the Correlation Matrix
corr_matrix = df.corr(method='pearson')
corr_matrix = np.abs(corr_matrix) * 100

# %%
#Plot a Correlation Matrix Heat Map
f, ax = plt.subplots(figsize=(8,8))
sns.heatmap(corr_matrix , cbar=True, annot=True, square=True,
            fmt='.0f', annot_kws={'size':8}, alpha=0.6)
plt.title('Correlation of foreign currencies', fontsize=16)
plt.show()

# %%
usd_cad_RETURNS_JB = sm.stats.stattools.jarque_bera(usd_cad_RETURNS.fillna(usd_cad_RETURNS.mean()).dropna())
aud_usd_RETURNS_JB = sm.stats.stattools.jarque_bera(aud_usd_RETURNS.fillna(aud_usd_RETURNS.mean()).dropna())
usd_jpy_RETURNS_JB = sm.stats.stattools.jarque_bera(usd_jpy_RETURNS.fillna(usd_jpy_RETURNS.mean()).dropna())
gbp_usd_RETURNS_JB = sm.stats.stattools.jarque_bera(gbp_usd_RETURNS.fillna(gbp_usd_RETURNS.mean()).dropna())
euro_usd_RETURNS_JB = sm.stats.stattools.jarque_bera(euro_usd_RETURNS.fillna(euro_usd_RETURNS.mean()).dropna())

# %%
print('Jarque Bera results for Cryptocurrencies: \nusd_cad_RETURNS  - ' + str(usd_cad_RETURNS_JB[0]) + '\naud_usd_RETURNS   - '+ str(aud_usd_RETURNS_JB[0])+ '\nusd_jpy_RETURNS    - '+ str(usd_jpy_RETURNS_JB[0])+ '\ngbp_usd_RETURNS    - '+ str(gbp_usd_RETURNS_JB[0])+ '\neuro_usd_RETURNS    - '+ str(euro_usd_RETURNS_JB[0]) )
# Out:
# Jarque Bera results for Cryptocurrencies:
# usd_cad_RETURNS  - 236.7504128321621
# aud_usd_RETURNS   - 989.5077442429439
# usd_jpy_RETURNS    - 3917.237481395882
# gbp_usd_RETURNS    - 551.58868180068
# euro_usd_RETURNS    - 111.18936697783447

# %%
## Testing for Stationarity of Return Series

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig, ax = plt.subplots(1,2,figsize=(16,4))
plot_acf(usd_cad_RETURNS.dropna(), ax=ax[0])
plot_pacf(usd_cad_RETURNS.dropna(), ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,4))
plot_acf(aud_usd_RETURNS.dropna(), ax=ax[0])
plot_pacf(aud_usd_RETURNS.dropna(), ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,4))
plot_acf(gbp_usd_RETURNS.dropna(), ax=ax[0])
plot_pacf(gbp_usd_RETURNS.dropna(), ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,4))
plot_acf(gbp_usd_RETURNS.dropna(), ax=ax[0])
plot_pacf(gbp_usd_RETURNS.dropna(), ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,4))
plot_acf(euro_usd_RETURNS.dropna(), ax=ax[0])
plot_pacf(euro_usd_RETURNS.dropna(), ax=ax[1])
plt.show()

# %%
## defining dataframe for foreign currency pairs  returns before and after covid

# %%
usd_cad_RETURNS= df['usd_cad'].pct_change(1)
aud_usd_RETURNS = df['aud_usd'].pct_change(1)
usd_jpy_RETURNS = df['usd_jpy'].pct_change(1)
gbp_usd_RETURNS = df['gbp_usd'].pct_change(1)
euro_usd_RETURNS = df['euro_usd'].pct_change(1)
Date=df['Date']

# %%
df4r=pd.concat([usd_cad_RETURNS,aud_usd_RETURNS,usd_jpy_RETURNS,gbp_usd_RETURNS,euro_usd_RETURNS,Date], axis=1)
df4r.dropna()
# Out:
#       usd_cad   aud_usd   usd_jpy   gbp_usd  euro_usd       Date
# 1    0.000390  0.001682 -0.000729  0.001248 -0.001881  19-Aug-21
# 2   -0.013332  0.011895  0.000182  0.008579  0.003084  18-Aug-21
# 3   -0.001976  0.002489 -0.001549 -0.001163 -0.000171  17-Aug-21
# 4   -0.004592  0.012140 -0.003103  0.008079  0.005893  16-Aug-21
# 5   -0.004693  0.004361  0.003113  0.000939  0.001189  13-Aug-21
# ..        ...       ...       ...       ...       ...        ...
# 684  0.001808  0.001121 -0.000276  0.004797  0.002972   7-Jan-19
# 685  0.005715 -0.004897 -0.001748 -0.004069 -0.007058   4-Jan-19
# 686  0.008599 -0.015045 -0.007924 -0.007465 -0.000088   3-Jan-19
# 687  0.006598 -0.002998  0.011238 -0.001900 -0.004476   2-Jan-19
# 688  0.004493  0.009737  0.007715  0.011422  0.010667   1-Jan-19
#
# [688 rows x 6 columns]

# %%
df4r = df4r.set_index('Date')

# %%
df4r
df4r.dropna()
# Out:
#             usd_cad   aud_usd   usd_jpy   gbp_usd  euro_usd
# Date
# 19-Aug-21  0.000390  0.001682 -0.000729  0.001248 -0.001881
# 18-Aug-21 -0.013332  0.011895  0.000182  0.008579  0.003084
# 17-Aug-21 -0.001976  0.002489 -0.001549 -0.001163 -0.000171
# 16-Aug-21 -0.004592  0.012140 -0.003103  0.008079  0.005893
# 13-Aug-21 -0.004693  0.004361  0.003113  0.000939  0.001189
# ...             ...       ...       ...       ...       ...
# 7-Jan-19   0.001808  0.001121 -0.000276  0.004797  0.002972
# 4-Jan-19   0.005715 -0.004897 -0.001748 -0.004069 -0.007058
# 3-Jan-19   0.008599 -0.015045 -0.007924 -0.007465 -0.000088
# 2-Jan-19   0.006598 -0.002998  0.011238 -0.001900 -0.004476
# 1-Jan-19   0.004493  0.009737  0.007715  0.011422  0.010667
#
# [688 rows x 5 columns]

# %%
dfb4covid=df4r.iloc[412:688]

# %%
dfb4covid
# Out:
#             usd_cad   aud_usd   usd_jpy   gbp_usd  euro_usd
# Date
# 22-Jan-20  0.000914 -0.000292  0.003197  0.001448  0.003529
# 21-Jan-20 -0.005101  0.000000  0.000273 -0.007078 -0.000811
# 20-Jan-20 -0.001607  0.004091  0.002913 -0.002913  0.001083
# 17-Jan-20  0.001303  0.000000 -0.000363 -0.000077 -0.000541
# 16-Jan-20 -0.001761  0.003783  0.000000  0.005228  0.004239
# ...             ...       ...       ...       ...       ...
# 8-Jan-19   0.004921 -0.004324  0.005362 -0.005552 -0.008750
# 7-Jan-19   0.001808  0.001121 -0.000276  0.004797  0.002972
# 4-Jan-19   0.005715 -0.004897 -0.001748 -0.004069 -0.007058
# 3-Jan-19   0.008599 -0.015045 -0.007924 -0.007465 -0.000088
# 2-Jan-19   0.006598 -0.002998  0.011238 -0.001900 -0.004476
#
# [276 rows x 5 columns]

# %%
dfb4covid.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd
# count  276.000000  276.000000  276.000000  276.000000  276.000000
# mean     0.000129    0.000081   -0.000014   -0.000132    0.000099
# std      0.003129    0.004255    0.003396    0.005019    0.003010
# min     -0.009703   -0.015045   -0.013492   -0.019795   -0.009549
# 25%     -0.001694   -0.002948   -0.002095   -0.002727   -0.001509
# 50%      0.000000    0.000287    0.000000    0.000387    0.000044
# 75%      0.001811    0.002814    0.001670    0.003225    0.001907
# max      0.009834    0.018443    0.013137    0.015311    0.010095

# %%
dfaftcovid=df4r.iloc[1:412]

# %%
dfaftcovid
# Out:
#             usd_cad   aud_usd   usd_jpy   gbp_usd  euro_usd
# Date
# 19-Aug-21  0.000390  0.001682 -0.000729  0.001248 -0.001881
# 18-Aug-21 -0.013332  0.011895  0.000182  0.008579  0.003084
# 17-Aug-21 -0.001976  0.002489 -0.001549 -0.001163 -0.000171
# 16-Aug-21 -0.004592  0.012140 -0.003103  0.008079  0.005893
# 13-Aug-21 -0.004693  0.004361  0.003113  0.000939  0.001189
# ...             ...       ...       ...       ...       ...
# 29-Jan-20 -0.000909  0.005060  0.000367 -0.005651 -0.001904
# 28-Jan-20 -0.003107  0.001333  0.001285  0.000538  0.000999
# 27-Jan-20  0.002813 -0.000296 -0.002199  0.001996 -0.000363
# 24-Jan-20 -0.003790  0.010059  0.003490  0.001762  0.000635
# 23-Jan-20 -0.001522  0.002636  0.001922  0.003441  0.002631
#
# [411 rows x 5 columns]

# %%
dfaftcovid.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd
# count  411.000000  411.000000  411.000000  411.000000  411.000000
# mean     0.000069   -0.000076    0.000005   -0.000073   -0.000128
# std      0.004960    0.007057    0.004966    0.006008    0.004355
# min     -0.020961   -0.021823   -0.031146   -0.025900   -0.014152
# 25%     -0.002456   -0.004014   -0.002199   -0.003698   -0.002927
# 50%      0.000166   -0.000407    0.000091   -0.000293   -0.000082
# 75%      0.002844    0.003885    0.002191    0.003247    0.002627
# max      0.018957    0.040103    0.028923    0.037630    0.020861

# %%
## testing for the difference between before and after covid parameters
from scipy import stats

# %%
##defining returns for the foreign currency pairs

# %%
usdcadaft=dfaftcovid['usd_cad']

# %%
usdcadb4=dfb4covid['usd_cad']

# %%
stats.ttest_ind(usdcadaft, usdcadb4)
# Out:
# Ttest_indResult(statistic=-0.17820142948666337, pvalue=0.858617473788728)

# %%
audusdaft=dfaftcovid['aud_usd']

# %%
audusdb4=dfb4covid['aud_usd']

# %%
stats.ttest_ind(audusdaft, audusdb4)
# Out:
# Ttest_indResult(statistic=-0.3309743581889038, pvalue=0.740765071505379)

# %%
usdjpyaft=dfaftcovid['usd_jpy']

# %%
usdjpyb4=dfb4covid['usd_jpy']

# %%
stats.ttest_ind(usdjpyaft, usdjpyb4)
# Out:
# Ttest_indResult(statistic=0.05661954588936141, pvalue=0.954864775031593)

# %%
gbpusdaft=dfaftcovid['gbp_usd']

# %%
gbpusdb4=dfb4covid['gbp_usd']

# %%
stats.ttest_ind(gbpusdaft, gbpusdb4)
# Out:
# Ttest_indResult(statistic=0.13500588686547316, pvalue=0.892646879505828)

# %%
eurousdaft=dfaftcovid['euro_usd']

# %%
eurousdb4=dfb4covid['euro_usd']

# %%
stats.ttest_ind(eurousdaft, eurousdb4)
# Out:
# Ttest_indResult(statistic=-0.7534389202736759, pvalue=0.4514450813684011)

# %%
##defining data frames for prices before and prices after covid
pb4covid=df.iloc[412:688]

paftcovid=df.iloc[1:412]

# %%
pb4covid.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd    euro_jpy
# count  276.000000  276.000000  276.000000  276.000000  276.000000  276.000000
# mean     1.325138    0.694871  109.042717    1.278480    1.118886  122.013841
# std      0.012694    0.014063    1.555646    0.033247    0.013195    2.630981
# min      1.296300    0.670200  105.290000    1.203400    1.089800  116.220000
# 25%      1.315875    0.683950  108.112500    1.254250    1.108675  120.357500
# 50%      1.325950    0.692300  108.840000    1.287700    1.118750  121.750000
# 75%      1.333400    0.708000  109.970000    1.304975    1.128425  124.462500
# max      1.357800    0.727200  112.170000    1.333700    1.154300  127.330000

# %%
paftcovid.describe()
# Out:
#           usd_cad     aud_usd     usd_jpy     gbp_usd    euro_usd    euro_jpy
# count  411.000000  411.000000  411.000000  411.000000  411.000000  411.000000
# mean     1.305027    0.720282  107.250584    1.324318    1.166050  125.026423
# std      0.057955    0.049629    2.266499    0.061484    0.045643    4.853023
# min      1.203200    0.574100  102.340000    1.148500    1.069000  114.570000
# 25%      1.258050    0.688950  105.400000    1.279800    1.125600  120.895000
# 50%      1.308100    0.728500  107.310000    1.322300    1.181300  125.330000
# 75%      1.340050    0.764000  109.235000    1.382200    1.203300  129.350000
# max      1.451000    0.796700  112.110000    1.420900    1.232500  133.950000

# %%
##testing for the difference between the (foreing currency pairs)prices before and after covid

# %%
pusdcadaft=paftcovid['usd_cad']

# %%
pusdcadb4=pb4covid['usd_cad']

# %%
stats.ttest_ind(pusdcadaft, pusdcadb4)
# Out:
# Ttest_indResult(statistic=-5.673210697797548, pvalue=2.0684545861438903e-08)

# %%
paudusdaft=paftcovid['aud_usd']

# %%
paudusdb4=pb4covid['aud_usd']

# %%
stats.ttest_ind(paudusdaft, paudusdb4)
# Out:
# Ttest_indResult(statistic=8.283984460408972, pvalue=6.260776817642093e-16)

# %%
pusdjpyaft=paftcovid['usd_jpy']

pusdjpyb4=pb4covid['usd_jpy']

# %%
stats.ttest_ind(pusdjpyaft, pusdjpyb4)
# Out:
# Ttest_indResult(statistic=-11.448289762168892, pvalue=6.86135795589923e-28)

# %%
pgbpusdaft=paftcovid['gbp_usd']

pgbpusdb4=pb4covid['gbp_usd']

# %%
stats.ttest_ind(pgbpusdaft, pgbpusdb4)
# Out:
# Ttest_indResult(statistic=11.322108022982832, pvalue=2.3174852169681384e-27)

# %%
peurousdaft=paftcovid['euro_usd']

peurousdb4=pb4covid['euro_usd']

# %%
stats.ttest_ind(peurousdaft, peurousdb4)
# Out:
# Ttest_indResult(statistic=16.70123658276978, pvalue=8.707806126157127e-53)
